# %%
import seaborn as sns
import matplotlib.pyplot as plt
x=sns.load_dataset("taxis")
plt.boxplot(x["total"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fdecc20ffa0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fdecc1fc580>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fdecc20fdf0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fdecc1fcb20>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fdecc1fcdf0>],
#  'means': []}
